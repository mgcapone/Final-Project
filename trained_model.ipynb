# %%
from scipy.stats import linregress
import numpy as np
import pandas as pd
import datetime as dt
import sklearn
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

# %%
# Call in portion of data for basic manipulation
df = pd.read_csv('./Data/data.csv')
df.head()
# df.describe()
# Out:
#    Date  Rot VH           Team  1st  2nd  Final Open  Close      ML    2H
# 0  1109  711  V    FloridaIntl   30   42     72  146  150.5   10000    79
# 1  1109  712  H  NorthCarolina   46   42     88   30   30.5  -30000  14.5
# 2  1109  713  V    MurrayState   26   44     70  132  139.5     700    73
# 3  1109  714  H     California   34   41     75   13   13.5   -1100     6
# 4  1109  715  V    AlcornState   28   32     60   NL     NL   16000    NL

# %%
#finding outlier games/teams
count_df = df['Team'].value_counts()
count_dict = count_df.to_dict()
df['Team Frequency'] = df['Team'].map(count_dict)

# %%
# encode the team names for easier training/testing
le = LabelEncoder()
le.fit(df['Team'])
team_code = le.transform(df['Team'])
df['Team Code'] = team_code
df.head()
# Out:
#    Date  Rot VH           Team  1st  2nd  Final Open  Close      ML    2H  \
# 0  1109  711  V    FloridaIntl   30   42     72  146  150.5   10000    79
# 1  1109  712  H  NorthCarolina   46   42     88   30   30.5  -30000  14.5
# 2  1109  713  V    MurrayState   26   44     70  132  139.5     700    73
# 3  1109  714  H     California   34   41     75   13   13.5   -1100     6
# 4  1109  715  V    AlcornState   28   32     60   NL     NL   16000    NL
#
#    Team Frequency  Team Code
# 0             270        107
# 1             382        232
# 2             313        211
# 3             344         46
# 4              78          9

# %%
track_df = pd.DataFrame(columns=['Team','Code'])


track_df['Team'] = df['Team'].unique()
track_df['Code'] = df['Team Code'].unique()

team_dict = dict(zip(track_df.Team, track_df.Code))
# team_dict

# %%
# Transferring home/away status to numeric
def home_away_func(row):
    if row['VH'] == 'H':
        return 1
    elif row['VH'] == 'V':
        return 0
    else:
        return 0.5

# %%
df['Home/Away/Neutral'] = df.apply(home_away_func, axis=1)
# df.head()

# %%
# Reorder to put entire game data on single row
odd = df.iloc[::2]
even = df.iloc[1::2]

# %%
merged_df = odd.reset_index(drop=True).merge(even.reset_index(drop=True), left_index=True, right_index=True)
merged_df.head()
# Out:
#    Date_x  Rot_x VH_x       Team_x  1st_x  2nd_x  Final_x Open_x Close_x  \
# 0    1109    711    V  FloridaIntl     30     42       72    146   150.5
# 1    1109    713    V  MurrayState     26     44       70    132   139.5
# 2    1109    715    V  AlcornState     28     32       60     NL      NL
# 3    1109    717    V     AlbanyNY     20     23       43     NL      NL
# 4    1111    727    V     DetroitU     32     29       61    142   140.5
#
#     ML_x  ... 1st_y  2nd_y  Final_y  Open_y  Close_y    ML_y  2H_y  \
# 0  10000  ...    46     42       88      30     30.5  -30000  14.5
# 1    700  ...    34     41       75      13     13.5   -1100     6
# 2  16000  ...    56     44      100      34       39  -48000    15
# 3   1500  ...    38     37       75      24       20   -3000     7
# 4   1350  ...    40     55       95      18       17   -2300   8.5
#
#   Team Frequency_y  Team Code_y  Home/Away/Neutral_y
# 0              382          232                  1.0
# 1              344           46                  1.0
# 2              361          251                  1.0
# 3              348          327                  1.0
# 4              344           46                  1.0
#
# [5 rows x 28 columns]

# %%
cleaned_df = merged_df.rename(columns = {'Date_x':'Date','VH_x':'Loc Team X','Team_x':'Team X','1st_x':'Team X 1st Half',
                                      '2nd_x':'Team X 2nd Half','Final_x':'Team X Final','VH_y':'Loc Team Y',
                                      'Team_y':'Team Y','1st_y':'Team Y 1st Half','2nd_y':'Team Y 2nd Half',
                                     'Final_y':'Team Y Final','Open_x':'Total Open','Close_x':'Total Close','ML_x':'Team X Moneyline',
                                        '2H_x':'2nd Half Total','Open_y':'Spread Open','Close_y':'Spread Close','ML_y':'Team Y Moneyline',
                                        '2H_y':'2nd Half Spread'})
cleaned_df.head()
# Out:
#    Date  Rot_x Loc Team X       Team X  Team X 1st Half  Team X 2nd Half  \
# 0  1109    711          V  FloridaIntl               30               42
# 1  1109    713          V  MurrayState               26               44
# 2  1109    715          V  AlcornState               28               32
# 3  1109    717          V     AlbanyNY               20               23
# 4  1111    727          V     DetroitU               32               29
#
#    Team X Final Total Open Total Close Team X Moneyline  ... Team Y 1st Half  \
# 0            72        146       150.5            10000  ...              46
# 1            70        132       139.5              700  ...              34
# 2            60         NL          NL            16000  ...              56
# 3            43         NL          NL             1500  ...              38
# 4            61        142       140.5             1350  ...              40
#
#    Team Y 2nd Half  Team Y Final  Spread Open  Spread Close  Team Y Moneyline  \
# 0               42            88           30          30.5            -30000
# 1               41            75           13          13.5             -1100
# 2               44           100           34            39            -48000
# 3               37            75           24            20             -3000
# 4               55            95           18            17             -2300
#
#   2nd Half Spread Team Frequency_y  Team Code_y  Home/Away/Neutral_y
# 0            14.5              382          232                  1.0
# 1               6              344           46                  1.0
# 2              15              361          251                  1.0
# 3               7              348          327                  1.0
# 4             8.5              344           46                  1.0
#
# [5 rows x 28 columns]

# %%
cleaned_df.drop(cleaned_df[cleaned_df['Total Close'] == 'NL'].index, inplace = True) 
cleaned_df.drop(cleaned_df[cleaned_df['Spread Close'] == 'NL'].index, inplace=True)
cleaned_df.drop(cleaned_df[cleaned_df['2nd Half Spread'] == 'NL'].index, inplace=True)
cleaned_df.drop(cleaned_df[cleaned_df['2nd Half Total'] == 'NL'].index, inplace=True)
cleaned_df.drop(cleaned_df[cleaned_df['Team X Moneyline'] == 'NL'].index, inplace=True)
cleaned_df.drop(cleaned_df[cleaned_df['Team Y Moneyline'] == 'NL'].index, inplace=True)

# %%
cleaned_df.drop(columns=['Total Open','Spread Open'])
cleaned_df.head()
# Out:
#    Date  Rot_x Loc Team X        Team X  Team X 1st Half  Team X 2nd Half  \
# 0  1109    711          V   FloridaIntl               30               42
# 1  1109    713          V   MurrayState               26               44
# 4  1111    727          V      DetroitU               32               29
# 7  1112    505          V  JamesMadison               25               19
# 8  1112    507          V  GeorgiaState               29               24
#
#    Team X Final Total Open Total Close Team X Moneyline  ... Team Y 1st Half  \
# 0            72        146       150.5            10000  ...              46
# 1            70        132       139.5              700  ...              34
# 4            61        142       140.5             1350  ...              40
# 7            44        149       140.5             1500  ...              34
# 8            53      137.5         135              450  ...              32
#
#    Team Y 2nd Half  Team Y Final  Spread Open  Spread Close  Team Y Moneyline  \
# 0               42            88           30          30.5            -30000
# 1               41            75           13          13.5             -1100
# 4               55            95           18            17             -2300
# 7               38            72         16.5            19             -2600
# 8               37            69           10          10.5              -600
#
#   2nd Half Spread Team Frequency_y  Team Code_y  Home/Away/Neutral_y
# 0            14.5              382          232                  1.0
# 1               6              344           46                  1.0
# 4             8.5              344           46                  1.0
# 7             8.5              361          251                  1.0
# 8             5.5              333          215                  1.0
#
# [5 rows x 28 columns]

# %%
cleaned_df = cleaned_df.loc[(cleaned_df['Team Frequency_x'] > 10) & (cleaned_df['Team Frequency_y'] > 10)]

# %%
# Find winner
def win_func(row):
    if row['Team X Final'] > row['Team Y Final']:
        return row['Team X']
    else:
        return row['Team Y']

cleaned_df['Winner'] = cleaned_df.apply(win_func, axis=1)

# %%
# Drop meaningless columns
shortened_df = cleaned_df.drop(columns=['Rot_x','Date_y','Rot_y','Total Open','Spread Open'])

# %%
# Convert objects to floats
shortened_df['Total Close'] = pd.to_numeric(shortened_df['Total Close'])
shortened_df['Spread Close'] = pd.to_numeric(shortened_df['Spread Close'])
shortened_df['2nd Half Spread'] = pd.to_numeric(shortened_df['2nd Half Spread'])
shortened_df['2nd Half Total'] = pd.to_numeric(shortened_df['2nd Half Total'])
shortened_df['Team X Moneyline'] = pd.to_numeric(shortened_df['Team X Moneyline'])
shortened_df['Team Y Moneyline'] = pd.to_numeric(shortened_df['Team Y Moneyline'])

# %%
###### Use the df.apply to create corrected columns then drop bad column
def spread_func(row):
    if row['Total Close'] < row['Spread Close']:
        return row['Total Close']
    else:
        return (row['Spread Close'] * -1)
    
def total_func(row):
    if row['Total Close'] < row['Spread Close']:
        return row['Spread Close']
    else:
        return row['Total Close']

# %%
shortened_df['Corrected Spread'] = shortened_df.apply(spread_func, axis=1)
shortened_df['Corrected Total'] = shortened_df.apply(total_func, axis=1)
shortened_df.head()
# Out:
#    Date Loc Team X        Team X  Team X 1st Half  Team X 2nd Half  \
# 0  1109          V   FloridaIntl               30               42
# 1  1109          V   MurrayState               26               44
# 4  1111          V      DetroitU               32               29
# 7  1112          V  JamesMadison               25               19
# 8  1112          V  GeorgiaState               29               24
#
#    Team X Final  Total Close  Team X Moneyline  2nd Half Total  \
# 0            72        150.5             10000            79.0
# 1            70        139.5               700            73.0
# 4            61        140.5              1350            73.5
# 7            44        140.5              1500            72.5
# 8            53        135.0               450            71.0
#
#    Team Frequency_x  ...  Team Y Final  Spread Close Team Y Moneyline  \
# 0               270  ...            88          30.5           -30000
# 1               313  ...            75          13.5            -1100
# 4               326  ...            95          17.0            -2300
# 7               312  ...            72          19.0            -2600
# 8               322  ...            69          10.5             -600
#
#   2nd Half Spread  Team Frequency_y  Team Code_y  Home/Away/Neutral_y  \
# 0            14.5               382          232                  1.0
# 1             6.0               344           46                  1.0
# 4             8.5               344           46                  1.0
# 7             8.5               361          251                  1.0
# 8             5.5               333          215                  1.0
#
#           Winner  Corrected Spread  Corrected Total
# 0  NorthCarolina             -30.5            150.5
# 1     California             -13.5            139.5
# 4     California             -17.0            140.5
# 7      OhioState             -19.0            140.5
# 8        NCState             -10.5            135.0
#
# [5 rows x 26 columns]

# %%
shortened_df['Team X Spread'] = shortened_df['Corrected Spread'] * -1
shortened_df['Team Y Spread'] = shortened_df['Corrected Spread']

# %%
### Create function to see who wins against the spread
### if they cover, they get a 1, if no cover or push, then 0
def team_to_cover(row):
    if (row['Team Y Final'] + row['Corrected Spread']) < row['Team X Final']:
        return 0
    elif (row['Team Y Final'] + row['Corrected Spread']) > row['Team X Final']:
        return 1
    else:
        return 0.5

# %%
# Team to cover key: 1 = Team Y, 0 = Team x, 0.5 = Push ATS
shortened_df['Team to Cover'] = shortened_df.apply(team_to_cover, axis=1)

# %%
# Check output
final_df = shortened_df
final_df.head(50)
# Out:
#     Date Loc Team X            Team X  Team X 1st Half  Team X 2nd Half  \
# 0   1109          V       FloridaIntl               30               42
# 1   1109          V       MurrayState               26               44
# 4   1111          V          DetroitU               32               29
# 7   1112          V      JamesMadison               25               19
# 8   1112          V      GeorgiaState               29               24
# 9   1113          V      CSNorthridge               20               43
# 10  1113          V      William&Mary               31               35
# 11  1113          V   YoungstownState               24               33
# 12  1113          V         MiamiOhio               42               29
# 13  1113          V    ClevelandState               25               37
# 15  1113          V        Valparaiso               38               40
# 16  1113          V        ArkansasLR               30               34
# 17  1113          V       NewOrleansU               32               27
# 18  1113          V     Massachusetts               35               32
# 19  1113          V      Pennsylvania               29               26
# 20  1113          V          ULMonroe               29               33
# 21  1113          V  NorthernIllinois               25               30
# 22  1113          V     LoyolaChicago               18               36
# 23  1113          V           Hofstra               27               38
# 24  1113          V            Drexel               29               33
# 25  1113          V      SouthFlorida               29               38
# 26  1113          V            IdahoU               47               47
# 27  1113          V        Georgetown               32               42
# 28  1113          V           Bradley               25               35
# 29  1113          V      NorthernIowa               23               48
# 30  1113          V        CalPolySLO               28               34
# 31  1113          V    NewMexicoState               26               42
# 32  1113          V          Stanford               32               32
# 33  1113          V           Pacific               25               30
# 36  1113          N      WiscGreenBay               30               26
# 37  1113          V           Samford               34               32
# 39  1113          V       WrightState               28               41
# 40  1113          N   LoyolaMarymount               45               42
# 44  1113          V     MoreheadState               25               34
# 45  1113          V      NCGreensboro               27               35
# 46  1113          V           Wofford               31               29
# 47  1113          V          StPeters               27               24
# 48  1113          V      NCWilmington               31               37
# 49  1113          V        AustinPeay               25               29
# 50  1113          V     TennesseeTech               22               28
# 51  1113          V             Siena               38               47
# 52  1113          V        IdahoState               24               44
# 53  1113          V             Rider               44               44
# 54  1113          V         UtahState               28               38
# 55  1113          V           Niagara               33               32
# 57  1114          V         Princeton               43               28
# 58  1114          V            Temple               40               36
# 59  1114          V         Creighton               46               34
# 60  1114          V           Cornell               26               45
# 62  1114          V      CalRiverside               22               29
#
#     Team X Final  Total Close  Team X Moneyline  2nd Half Total  \
# 0             72        150.5             10000            79.0
# 1             70        139.5               700            73.0
# 4             61        140.5              1350            73.5
# 7             44        140.5              1500            72.5
# 8             53        135.0               450            71.0
# 9             63        142.0              2000            74.5
# 10            66        136.0              2250            73.0
# 11            57        137.0              1150            73.0
# 12            71          1.5              -125            70.0
# 13            62          1.0              -120             3.0
# 15            78          1.5              -120             2.0
# 16            64        139.5              1400            74.5
# 17            59        126.5              1100            71.0
# 18            67        147.0               160            78.5
# 19            55        139.0              1000            72.5
# 20            62        140.0              1150            74.0
# 21            55        132.5               775            70.5
# 22            54        139.0              1800            71.0
# 23            65        145.5              3000            75.5
# 24            67        121.5               190            66.0
# 25            67        123.0              -102            68.0
# 26            94        134.0               450            75.0
# 27            74         10.5              -600             5.5
# 28            60        143.0               700            73.0
# 29            71          3.5              -175             1.5
# 30            62        131.0               575            71.0
# 31            68        147.5               360            77.0
# 32            64          1.0              -115             0.5
# 33            67          4.5              -170             1.5
# 36            56        137.5               120            72.5
# 37            66        122.0               475            67.0
# 39            69        133.5              1000            71.5
# 40            87        148.5               310            81.0
# 44            59        135.0              1600            71.5
# 45            62        133.5              6000            71.5
# 46            60        136.5              1000            70.5
# 47            51        134.0              1300            70.0
# 48            68        152.5               400            80.5
# 49            54        160.5              2750            80.0
# 50            50        143.0              2000            74.0
# 51            85         14.0             -1200             5.0
# 52            68        129.0               925            69.5
# 53            88        146.0              1000            80.0
# 54            66          3.0              -155            69.0
# 55            65        145.0               210            77.0
# 57            71        115.0               240            66.5
# 58            76          7.5              -340            70.5
# 59            80        140.5               280            77.5
# 60            71        145.5               245            74.5
# 62            51        134.5              1050            70.5
#
#     Team Frequency_x  ...  2nd Half Spread  Team Frequency_y Team Code_y  \
# 0                270  ...             14.5               382         232
# 1                313  ...              6.0               344          46
# 4                326  ...              8.5               344          46
# 7                312  ...              8.5               361         251
# 8                322  ...              5.5               333         215
# 9                295  ...              7.0               348         269
# 10               291  ...             10.5               336          71
# 11               293  ...              4.5               357         402
# 12               316  ...              0.0               290         349
# 13               321  ...             70.0               317         315
# 15               326  ...             68.0               296          24
# 16               306  ...              7.0               336         198
# 17                86  ...              8.0               324         117
# 18               317  ...              1.5               294          53
# 19               268  ...              6.5               323         259
# 20               291  ...              6.0               317         160
# 21               304  ...              5.5               318         246
# 22               319  ...              8.0               329         156
# 23               311  ...              9.5               376         155
# 24               321  ...              3.0               324         319
# 25               323  ...              0.0               310         284
# 26               274  ...              8.0               310         366
# 27               320  ...             68.0               283         351
# 28               327  ...              6.0               347          23
# 29               336  ...             61.0               298          81
# 30               298  ...              4.0               314         294
# 31               230  ...              3.0               333         288
# 32               338  ...             71.0               313         292
# 33               320  ...             66.5               310         261
# 36               321  ...              3.0               316         353
# 37               290  ...              7.0               324         158
# 39               328  ...              5.5               343         383
# 40               317  ...              4.5               321          29
# 44               311  ...              8.0               382         159
# 45               306  ...             12.0               382          90
# 46               310  ...             10.5               327         262
# 47               289  ...             11.0               326         301
# 48               305  ...              2.5               289          11
# 49               301  ...             12.5               348         332
# 50               274  ...              8.0               345         196
# 51               309  ...             81.0               279         335
# 52               278  ...              4.5               329         149
# 53               308  ...              9.5               313         199
# 54               320  ...              0.5               310         384
# 55               317  ...              3.5               312          21
# 57               260  ...              5.0               303          54
# 58               342  ...              0.5               298          78
# 59               349  ...              6.0               339          77
# 60               245  ...              4.5               335           3
# 62               286  ...              4.5               332         225
#
#    Home/Away/Neutral_y          Winner  Corrected Spread  Corrected Total  \
# 0                  1.0   NorthCarolina             -30.5            150.5
# 1                  1.0      California             -13.5            139.5
# 4                  1.0      California             -17.0            140.5
# 7                  1.0       OhioState             -19.0            140.5
# 8                  1.0         NCState             -10.5            135.0
# 9                  1.0          Purdue             -22.5            142.0
# 10                 1.0     Connecticut             -23.5            136.0
# 11                 1.0          Xavier             -16.5            137.0
# 12                 1.0          Towson               1.5            125.0
# 13                 1.0   StBonaventure               1.0            134.0
# 15                 1.0       BallState               1.5            120.0
# 16                 1.0     Mississippi             -16.5            139.5
# 17                 1.0         Georgia             -16.0            126.5
# 18                 1.0  CentralFlorida              -4.0            147.0
# 19                 1.0       PennState             -14.5            139.0
# 20                 1.0             LSU             -16.0            140.0
# 21                 1.0    Northwestern             -14.0            132.5
# 22                 1.0     KansasState             -21.5            139.0
# 23                 1.0          Kansas             -25.0            145.5
# 24                 1.0       StJosephs              -5.0            121.5
# 25                 1.0    SouthFlorida              -1.0            123.0
# 26                 1.0          IdahoU             -10.0            134.0
# 27                 1.0      Georgetown              10.5            126.0
# 28                 1.0             BYU             -13.0            143.0
# 29                 1.0    NorthernIowa               3.5            118.0
# 30                 1.0    SanFrancisco             -12.0            131.0
# 31                 1.0    SaintMarysCA              -9.0            147.5
# 32                 1.0        SanDiego               1.0            130.0
# 33                 1.0         Pacific               4.5            127.0
# 36                 0.5             UAB              -2.5            137.5
# 37                 1.0       KentState             -10.5            122.0
# 39                 1.0     WashingtonU             -15.0            133.5
# 40                 0.5      BoiseState              -8.0            148.5
# 44                 1.0        Kentucky             -17.5            135.0
# 45                 1.0            Duke             -31.0            133.5
# 46                 1.0      Pittsburgh             -15.0            136.5
# 47                 1.0       SetonHall             -17.5            134.0
# 48                 1.0   AppalachianSt              -9.5            152.5
# 49                 1.0       Tennessee             -24.5            160.5
# 50                 1.0       Minnesota             -22.5            143.0
# 51                 1.0           Siena              14.0            157.5
# 52                 1.0       IowaState             -15.0            129.0
# 53                 1.0           Rider             -15.0            146.0
# 54                 1.0       UtahState               3.0            134.5
# 55                 1.0          Auburn              -5.5            145.0
# 57                 1.0       Princeton              -6.5            115.0
# 58                 1.0          Temple               7.5            134.0
# 59                 1.0          Dayton              -7.5            140.5
# 60                 1.0         Cornell              -6.5            145.5
# 62                 1.0       NewMexico             -15.0            134.5
#
#     Team X Spread  Team Y Spread  Team to Cover
# 0            30.5          -30.5            0.0
# 1            13.5          -13.5            0.0
# 4            17.0          -17.0            1.0
# 7            19.0          -19.0            1.0
# 8            10.5          -10.5            1.0
# 9            22.5          -22.5            1.0
# 10           23.5          -23.5            0.0
# 11           16.5          -16.5            1.0
# 12           -1.5            1.5            1.0
# 13           -1.0            1.0            1.0
# 15           -1.5            1.5            1.0
# 16           16.5          -16.5            1.0
# 17           16.0          -16.0            0.0
# 18            4.0           -4.0            1.0
# 19           14.5          -14.5            1.0
# 20           16.0          -16.0            1.0
# 21           14.0          -14.0            1.0
# 22           21.5          -21.5            1.0
# 23           25.0          -25.0            1.0
# 24            5.0           -5.0            1.0
# 25            1.0           -1.0            0.0
# 26           10.0          -10.0            0.0
# 27          -10.5           10.5            0.0
# 28           13.0          -13.0            0.0
# 29           -3.5            3.5            0.0
# 30           12.0          -12.0            0.0
# 31            9.0           -9.0            1.0
# 32           -1.0            1.0            1.0
# 33           -4.5            4.5            1.0
# 36            2.5           -2.5            1.0
# 37           10.5          -10.5            0.0
# 39           15.0          -15.0            0.0
# 40            8.0           -8.0            0.0
# 44           17.5          -17.5            0.0
# 45           31.0          -31.0            1.0
# 46           15.0          -15.0            0.0
# 47           17.5          -17.5            0.0
# 48            9.5           -9.5            1.0
# 49           24.5          -24.5            1.0
# 50           22.5          -22.5            1.0
# 51          -14.0           14.0            0.0
# 52           15.0          -15.0            1.0
# 53           15.0          -15.0            0.0
# 54           -3.0            3.0            0.0
# 55            5.5           -5.5            0.0
# 57            6.5           -6.5            0.0
# 58           -7.5            7.5            0.0
# 59            7.5           -7.5            1.0
# 60            6.5           -6.5            0.0
# 62           15.0          -15.0            1.0
#
# [50 rows x 29 columns]

# %%
predict_winner_df = final_df.drop(['Date','Team X 1st Half','Team X 2nd Half','Team X Final',
                                  'Total Close','2nd Half Total','Team X','Team Y',
                                   'Team Y 1st Half','Team Y 2nd Half','Team Y Final',
                                   'Spread Close','2nd Half Spread','Winner','Corrected Spread',
                                  'Loc Team X','Loc Team Y','Team Frequency_x','Team Frequency_y',
                                  ], axis=1)
predict_winner_df.head()
# Out:
#    Team X Moneyline  Team Code_x  Home/Away/Neutral_x  Team Y Moneyline  \
# 0             10000          107                  0.0            -30000
# 1               700          211                  0.0             -1100
# 4              1350           84                  0.0             -2300
# 7              1500          154                  0.0             -2600
# 8               450          119                  0.0              -600
#
#    Team Code_y  Home/Away/Neutral_y  Corrected Total  Team X Spread  \
# 0          232                  1.0            150.5           30.5
# 1           46                  1.0            139.5           13.5
# 4           46                  1.0            140.5           17.0
# 7          251                  1.0            140.5           19.0
# 8          215                  1.0            135.0           10.5
#
#    Team Y Spread  Team to Cover
# 0          -30.5            0.0
# 1          -13.5            0.0
# 4          -17.0            1.0
# 7          -19.0            1.0
# 8          -10.5            1.0

# %%
x = predict_winner_df.drop(['Team to Cover'], axis=1)
y = predict_winner_df['Team to Cover']

print(x.shape, y.shape)
# Out:
# (39349, 9) (39349,)

# %%
y.nunique()
# Out:
# 3

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

# %%
scalar = StandardScaler()

# %%
scalar.fit(x_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train_scaled = scalar.transform(x_train)

# %%
x_test_scaled = scalar.transform(x_test)

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=9))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\marcg\Anaconda\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               1000
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 21,503
# Trainable params: 21,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    x_train_scaled,
    y_train,
    epochs=200,
    shuffle=True,
    verbose=2
)
# Out:
# Train on
# 29511/29511 - 11s - loss: 0.5945 - acc: 0.6481
# Epoch 189/200
# 29511/29511 - 10s - loss: 0.5937 - acc: 0.6461
# Epoch 190/200
# 29511/29511 - 9s - loss: 0.5947 - acc: 0.6456
# Epoch 191/200
# 29511/29511 - 14s - loss: 0.5933 - acc: 0.6470
# Epoch 192/200
# 29511/29511 - 9s - loss: 0.5933 - acc: 0.6450
# Epoch 193/200
# 29511/29511 - 12s - loss: 0.5921 - acc: 0.6472
# Epoch 194/200
# 29511/29511 - 16s - loss: 0.5933 - acc: 0.6486
# Epoch 195/200
# 29511/29511 - 10s - loss: 0.5915 - acc: 0.6476
# Epoch 196/200
# 29511/29511 - 15s - loss: 0.5918 - acc: 0.6505
# Epoch 197/200
# 29511/29511 - 13s - loss: 0.5891 - acc: 0.6490
# Epoch 198/200
# 29511/29511 - 13s - loss: 0.5893 - acc: 0.6515
# Epoch 199/200
# 29511/29511 - 18s - loss: 0.5911 - acc: 0.6476
# Epoch 200/200
# 29511/29511 - 9s - loss: 0.5897 - acc: 0.6497

# %%
# model_array = ['xml','teamxcode','locxcode','yml','teamycode','locycode','total','xspread','yspread']

# %%
model.save('second_model.h5')

# %%
encoded_predictions = model.predict_classes(x_test_scaled[:5])
print(encoded_predictions)
# Out:
# [0 0 0 0 0]

# %%
# print(x_train_scaled)
# Out:
# [[-0.08466278 -0.11541212  2.67604706 ... -1.66787674 -0.10082904
#    0.10082904]
#  [ 1.29104209 -1.20899688 -0.37368551 ... -0.50188496  2.0253552
#   -2.0253552 ]
#  [-0.07615327 -1.1321042  -0.37368551 ...  1.6435399   0.0206672
#   -0.0206672 ]
#  ...
#  [ 0.28408285  1.21739431 -0.37368551 ... -1.2481197   1.66086648
#   -1.66086648]
#  [-0.0960088  -0.27774111 -0.37368551 ... -0.82836266 -0.40456965
#    0.40456965]
#  [-0.2690356  -0.10686849 -0.37368551 ... -0.36196595 -1.61953208
#    1.61953208]]

# %%
kansas_tcu = [-430,155,0,315,328,1,131,-8,8]
kansas_tcu_output = model.predict_classes(kansas_tcu[0:8])
print(kansas_tcu_output)

# %%
kansas_tcu_output = list(team_dict.keys())[list(team_dict.values()).index(kansas_tcu)]
print(kansas_tcu_output)

# %%
umiami_fsu = [700,191,0,-1200,108,1,144,13.5,-13.5]
model.predict(umiami_fsu)

# %%
umiami_fsu_output = list(team_dict.keys())[list(team_dict.values()).index(umiami_fsu)]
print(umiami_fsu_output)

# %%
auburn_lsu = [175,160,0,-210,21,1,155.5,4.5,-4.5]
model.predict(auburn_lsu)

# %%
auburn_lsu_output = list(team_dict.keys())[list(team_dict.values()).index(auburn_lsu)]
print(auburn_lsu_output)

# %%
msu_mich = [120,194,0,-140,193,1,142.5,3,-3]
model.predict(msu_mich)

# %%
msu_mich_output = list(team_dict.keys())[list(team_dict.values()).index(msu_mich)]
print(msu_mich_output)

# %%
uk_tenn = [-165,159,0,145,332,1,132.5,-3.5,3.5]
model.predict(uk_tenn)

# %%
uk_tenn_output = list(team_dict.keys())[list(team_dict.values()).index(uk_tenn)]
print(uk_tenn_output)
